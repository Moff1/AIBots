# %%
import os
from typing import List, Optional, Literal, Any, Dict
from fastapi import FastAPI, HTTPException, Header, Depends
from pydantic import BaseModel, Field
from notion_client import Client
from notion_client.errors import APIResponseError

# %%
# --- SET THESE ---
NOTION_SECRET = "ntn_X3620961771at2knhAAXOx8kGlOiIQ9GKV0P9x69MT90xm"
PAGE_ID = "2880d7d37deb8082baf6cccb334a830d"  # You can shorten to just the UUID part
# Initialize client
notion = Client(auth=NOTION_SECRET)

# Example 1: get page metadata
page = notion.pages.retrieve(PAGE_ID)
print("📄 Page title or info:")
print(page)

# Example 2: list blocks inside the page
blocks = notion.blocks.children.list(PAGE_ID)
print("\n🧱 First few blocks:")
for b in blocks["results"][:5]:
    print(f"- {b['type']} (id: {b['id']})")

# Example 3: append a new paragraph block
new_block = notion.blocks.children.append(
    block_id=PAGE_ID,
    children=[
        {
            "object": "block",
            "type": "paragraph",
            "paragraph": {"rich_text": [{"type": "text", "text": {"content": "Hello from local Python!"}}]},
        }
    ],
)
print("\n✅ Appended block:")
print(new_block)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\Users\moffa\AppData\Local\Programs\Python\Python313\Lib\site-packages\notion_client\client.py:149, in BaseClient._parse_response(self, response)
#     148 try:
# --> 149     response.raise_for_status()
#     150 except httpx.HTTPStatusError as error:
#
# File c:\Users\moffa\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://api.notion.com/v1/pages/2740d7d37deb807aa70ee573626356f4'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# During handling of the above exception, another exception occurred:
#
# APIResponseError                          Traceback (most recent call last)
# Cell In[2], line 9
#       6 notion = Client(auth=NOTION_SECRET)
#       8 # Example 1: get page metadata
# ----> 9 page = notion.pages.retrieve(PAGE_ID)
#      10 print("📄 Page title or info:")
#      11 print(page)
#
# File c:\Users\moffa\AppData\Local\Programs\Python\Python313\Lib\site-packages\notion_client\api_endpoints.py:239, in PagesEndpoint.retrieve(self, page_id, **kwargs)
#     234 def retrieve(self, page_id: str, **kwargs: Any) -> SyncAsync[Any]:
#     235     """Retrieve a [Page object](https://developers.notion.com/reference/page) using the ID specified.
#     236
#     237     *[🔗 Endpoint documentation](https://developers.notion.com/reference/retrieve-a-page)*
#     238     """  # noqa: E501
# --> 239     return self.parent.request(
#     240         path=f"pages/{page_id}",
#     241         method="GET",
#     242         query=pick(kwargs, "filter_properties"),
#     243         auth=kwargs.get("auth"),
#     244     )
#
# File c:\Users\moffa\AppData\Local\Programs\Python\Python313\Lib\site-packages\notion_client\client.py:227, in Client.request(self, path, method, query, body, form_data, auth)
#     225 except httpx.TimeoutException:
#     226     raise RequestTimeoutError()
# --> 227 return self._parse_response(response)
#
# File c:\Users\moffa\AppData\Local\Programs\Python\Python313\Lib\site-packages\notion_client\client.py:157, in BaseClient._parse_response(self, response)
#     155         code = None
#     156     if code and is_api_error_code(code):
# --> 157         raise APIResponseError(response, body["message"], code)
#     158     raise HTTPResponseError(error.response)
#     160 body = response.json()
#
# APIResponseError: API token is invalid.
